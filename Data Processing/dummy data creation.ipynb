# %%
import random
import plotly.express as px

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
X1, _ = make_blobs(n_samples=500, centers=1, cluster_std=1.9, random_state=0)
ratings1 = np.array([random.choices(ratings, k=1, weights=[0,0,3,3,7,9,8,6,5])[0] for _ in range(500)])
genre1 = ['Hip-Hop']*len(X1) 

first = np.concatenate([X1,np.array(ratings1).reshape(-1,1),np.array(genre1).reshape(-1,1)],axis=-1)


X2, _ = make_blobs(n_samples=120, centers=1, cluster_std=0.6, random_state=13)
ratings2 = np.array([random.choices(ratings, k=1, weights=[0,1,2,9,6,5,2,1,0])[0] for _ in range(120)])
genre2 = ['Jazz']*len(X2) 
second = np.concatenate([X2,np.array(ratings2).reshape(-1,1),np.array(genre2).reshape(-1,1)],axis=-1)


X3, _ = make_blobs(n_samples=25, centers=1, cluster_std=0.4, random_state=9)
ratings3 = np.array([random.choices(ratings, k=1, weights=[0,0,3,6,6,7,8,9,8])[0] for _ in range(25)])
genre3 = ['Pop']*len(X3) 
third = np.concatenate([X3,np.array(ratings3).reshape(-1,1),np.array(genre3).reshape(-1,1)],axis=-1)


X4, _ = make_blobs(n_samples=80, centers=1, cluster_std=0.5, random_state=7)
ratings4 = np.array([random.choices(ratings, k=1, weights=[0,1,2,7,8,9,2,1,0])[0] for _ in range(80)])
genre4 = ['Blues']*len(X4) 
fourth = np.concatenate([X4,np.array(ratings4).reshape(-1,1),np.array(genre4).reshape(-1,1)],axis=-1)


X5, _ = make_blobs(n_samples=200, centers=1, cluster_std=1.3, random_state=8)
ratings5 = np.array([random.choices(ratings, k=1, weights=[5,6,9,7,7,3,2,1,1])[0] for _ in range(200)])
genre5 = ['Classical']*len(X5)
fifth = np.concatenate([X5,np.array(ratings5).reshape(-1,1),np.array(genre5).reshape(-1,1)],axis=-1)

# %%
import random
import time
    
def str_time_prop(start, end, time_format, prop):
    """Get a time at a proportion of a range of two formatted times.

    start and end should be strings specifying times formatted in the
    given format (strftime-style), giving an interval [start, end].
    prop specifies how a proportion of the interval to be taken after
    start.  The returned time will be in the specified format.
    """

    stime = time.mktime(time.strptime(start, time_format))
    etime = time.mktime(time.strptime(end, time_format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(time_format, time.localtime(ptime))


def random_date(start, end, prop):
    return str_time_prop(start, end, '%m/%d/%Y %I:%M %p', prop)

# %%
dataframe = pd.DataFrame(np.concatenate([first,second,third,fourth,fifth]),columns = ['enc1','enc2', 'rating', 'genre'])
timestamps = [random_date("1/1/2023 12:00 AM", "1/7/2023 12:00 AM", random.random()) for i in range(len(dataframe)//10)] + [random_date("1/7/2023 12:00 AM", "1/14/2023 12:00 AM", random.random()) for i in range((len(dataframe)*3)//10)] + [random_date("1/14/2023 12:00 AM", "1/21/2023 12:00 AM", random.random()) for i in range((len(dataframe)*2)//10)] + [random_date("1/21/2023 12:00 AM", "1/30/2023 12:00 AM", random.random()) for i in range((len(dataframe)*4)//10)]
timestamps += [random_date("1/21/2023 12:00 AM", "1/30/2023 12:00 AM", random.random()) for i in range(len(dataframe) - len(timestamps))]
dataframe.index = pd.to_datetime(timestamps)
dataframe = dataframe.sort_index()
dataframe[['enc1','enc2']] = dataframe[['enc1','enc2']].astype(float)

# %%
px.scatter(data_frame=dataframe,x='enc1',y='enc2',color='genre')
# Out:
# <div>                            <div id="4dd4ca60-1f4e-4548-a6a7-0a26d1fe26b1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4dd4ca60-1f4e-4548-a6a7-0a26d1fe26b1")) {                    Plotly.newPlot(                        "4dd4ca60-1f4e-4548-a6a7-0a26d1fe26b1",                        [{"hovertemplate":"genre=Hip-Hop<br>enc1=%{x}<br>enc2=%{y}<extra></extra>","legendgroup":"Hip-Hop","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Hip-Hop","orientation":"v","showlegend":true,"type":"scatter","x":[3.2335266840158683,-0.5222015050213007,0.5591421247171899,-1.7691162996929108,0.2173169229470323,-1.220476541915139,1.970495733556827,-0.40236494053431504,1.6201879164567896,2.497343205065389,0.3835154735056905,-0.7503800887757057
# ...

# %%
px.line(dataframe.groupby(pd.Grouper(freq='24h')).count()['enc1'])
# Out:
# <div>                            <div id="4941cc30-8bbe-426a-b5ea-a5c28f1b48fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4941cc30-8bbe-426a-b5ea-a5c28f1b48fc")) {                    Plotly.newPlot(                        "4941cc30-8bbe-426a-b5ea-a5c28f1b48fc",                        [{"hovertemplate":"variable=enc1<br>index=%{x}<br>value=%{y}<extra></extra>","legendgroup":"enc1","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"enc1","orientation":"v","showlegend":true,"type":"scatter","x":["2023-01-01T00:00:00","2023-01-02T00:00:00","2023-01-03T00:00:00","2023-01-04T00:00:00","2023-01-05T00:00:00","2023-01-06T00:00:00","2023-01-07T00:00:00","2023-01-08T00:00:00","2023-01-09T00:00:00","2023-01-10T00
# ...

# %%
dataframe.to_csv('D:/Projects/Orpheus_ai/DataSet/DummyData.csv')
